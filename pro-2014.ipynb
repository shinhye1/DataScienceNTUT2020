# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("studentsdata2014.csv")
df.head(5)
# Out:
#   Continent    Country  \
# 0      Asia      China
# 1      Asia   Malaysia
# 2      Asia  Hong Kong
# 3      Asia      Japan
# 4      Asia      Macao
#
#    Degree Students-Officially Studying Degrees Foreign Students  \
# 0                                                  0
# 1                                               3671
# 2                                                  0
# 3                                                698
# 4                                                  0
#
#    Degree Students-Overseas Students (including Hong Kong and Macao)  \
# 0                                                  0
# 1                                               6254
# 2                                               5814
# 3                                                177
# 4                                               4693
#
#    Degree Students-Officially Studying Degrees Land Students  \
# 0                                               5881
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Non-degree Students-Foreign Exchange Students  \
# 0                                              0
# 1                                             35
# 2                                            193
# 3                                            494
# 4                                             10
#
#    Non-degree Students-Foreign Short-Term Study and personal selection  \
# 0                                                  0
# 1                                                839
# 2                                                220
# 3                                               1423
# 4                                                  3
#
#    Non-degree students-college students with Chinese Language Center  \
# 0                                                377
# 1                                                 85
# 2                                                 59
# 3                                               3024
# 4                                                 17
#
#    Non-degree students-mainland students  Non-degree students-Haiqing class  \
# 0                                  27030                                  0
# 1                                      0                               2402
# 2                                      0                                  0
# 3                                      0                                  0
# 4                                      0                                  0
#
#    Overseas special classe  Total    Per million
# 0                        0  33288  320773.989631
# 1                       99  13286     398.132571
# 2                        0   6286     233.317926
# 3                        0   5816    2013.080872
# 4                        0   4723   59624.051608

# %%
df['DegreeF']=df['Degree Students-Officially Studying Degrees Foreign Students']
df['DegreeN']=df['Degree Students-Officially Studying Degrees Land Students']
df['NonDegreeF']=df['Non-degree Students-Foreign Exchange Students']+df['Non-degree Students-Foreign Short-Term Study and personal selection']+df['Non-degree students-college students with Chinese Language Center']
df['DegreeO']=df['Degree Students-Overseas Students (including Hong Kong and Macao)']+df['Overseas special classe']
df['NonDegreeN']=df['Non-degree students-Haiqing class']+df['Non-degree students-mainland students']
col=['Continent','DegreeF','DegreeN','DegreeO','NonDegreeF','NonDegreeN','Total']
df2=df[col]
df2=df2.groupby(['Continent'])['DegreeF','DegreeN','DegreeO','NonDegreeF','NonDegreeN','Total'].sum()
df2.head()
# Out:
#            DegreeF  DegreeN  DegreeO  NonDegreeF  NonDegreeN  Total
# Continent
# Africa         627        0       97         270           0    994
# America       1546        0      743        3914           4   6207
# Asia         11122     5881    19628       14312       29536  80080
# Europe         574        0       19        5042           0   5635
# Oceania        194        0       46         489           0    729

# %%
bin_labels = ['LowDegreeF','MedDegreeF','TopDegreeF']
df['DegreeF'] = pd.cut(df['DegreeF'],bins=3,labels=bin_labels)
bin_labels = ['LowDegreeN','MedDegreeN','TopDegreeN']
df['DegreeN'] = pd.cut(df['DegreeN'],bins=3,labels=bin_labels)
bin_labels = ['LowDegreeO','MedDegreeO','TopDegreeO']
df['DegreeO'] = pd.cut(df['DegreeO'],bins=3,labels=bin_labels)
bin_labels = ['LowNonDegreeF','MedNonDegreeF','TopNonDegreeF']
df['NonDegreeF'] = pd.cut(df['NonDegreeF'],bins=3,labels=bin_labels)
bin_labels = ['LowNonDegreeN','MedNonDegreeN','TopNonDegreeN']
df['NonDegreeN'] = pd.cut(df['NonDegreeN'],bins=3,labels=bin_labels)
col1=['DegreeF','DegreeN','DegreeO','NonDegreeF','NonDegreeN']
df1=df[col1]
df1.head(5)
# Out:
#       DegreeF     DegreeN     DegreeO     NonDegreeF     NonDegreeN
# 0  LowDegreeF  TopDegreeN  LowDegreeO  LowNonDegreeF  TopNonDegreeN
# 1  TopDegreeF  LowDegreeN  TopDegreeO  LowNonDegreeF  LowNonDegreeN
# 2  LowDegreeF  LowDegreeN  TopDegreeO  LowNonDegreeF  LowNonDegreeN
# 3  LowDegreeF  LowDegreeN  LowDegreeO  TopNonDegreeF  LowNonDegreeN
# 4  LowDegreeF  LowDegreeN  TopDegreeO  LowNonDegreeF  LowNonDegreeN

# %%
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_new=te.fit(df1.values).transform(df1.values)
df_new=pd.DataFrame(te_new, columns=te.columns_)
df_new.head(5)
# Out:
#    LowDegreeF  LowDegreeN  LowDegreeO  LowNonDegreeF  LowNonDegreeN  \
# 0        True       False        True           True          False
# 1       False        True       False           True           True
# 2        True        True       False           True           True
# 3        True        True        True          False           True
# 4        True        True       False           True           True
#
#    MedDegreeF  MedNonDegreeF  TopDegreeF  TopDegreeN  TopDegreeO  \
# 0       False          False       False        True       False
# 1       False          False        True       False        True
# 2       False          False       False       False        True
# 3       False          False       False       False       False
# 4       False          False       False       False        True
#
#    TopNonDegreeF  TopNonDegreeN
# 0          False           True
# 1          False          False
# 2          False          False
# 3           True          False
# 4          False          False

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules
ans=fpgrowth(df_new,min_support=0.97, use_colnames=True)
ans.head(5)
# Out:
#     support         itemsets
# 0  0.979866  (LowNonDegreeF)
# 1  0.979866     (LowDegreeO)
# 2  0.979866     (LowDegreeF)
# 3  0.993289  (LowNonDegreeN)
# 4  0.993289     (LowDegreeN)

# %%
fp=association_rules(ans,metric='lift',min_threshold=1)
fp=fp.sort_values(['confidence','lift'],ascending=[False, False])
fp.head(15)
# Out:
#                        antecedents                     consequents  \
# 0      (LowDegreeN, LowNonDegreeF)                 (LowNonDegreeN)
# 1   (LowNonDegreeN, LowNonDegreeF)                    (LowDegreeN)
# 4         (LowDegreeN, LowDegreeO)                 (LowNonDegreeN)
# 5      (LowNonDegreeN, LowDegreeO)                    (LowDegreeN)
# 8         (LowDegreeN, LowDegreeF)                 (LowNonDegreeN)
# 9      (LowNonDegreeN, LowDegreeF)                    (LowDegreeN)
# 12                    (LowDegreeN)                 (LowNonDegreeN)
# 13                 (LowNonDegreeN)                    (LowDegreeN)
# 2                     (LowDegreeN)  (LowNonDegreeN, LowNonDegreeF)
# 3                  (LowNonDegreeN)     (LowDegreeN, LowNonDegreeF)
# 6                     (LowDegreeN)     (LowNonDegreeN, LowDegreeO)
# 7                  (LowNonDegreeN)        (LowDegreeN, LowDegreeO)
# 10                    (LowDegreeN)     (LowNonDegreeN, LowDegreeF)
# 11                 (LowNonDegreeN)        (LowDegreeN, LowDegreeF)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.973154            0.993289  0.973154     1.00000  1.006757
# 1             0.973154            0.993289  0.973154     1.00000  1.006757
# 4             0.973154            0.993289  0.973154     1.00000  1.006757
# 5             0.973154            0.993289  0.973154     1.00000  1.006757
# 8             0.973154            0.993289  0.973154     1.00000  1.006757
# 9             0.973154            0.993289  0.973154     1.00000  1.006757
# 12            0.993289            0.993289  0.993289     1.00000  1.006757
# 13            0.993289            0.993289  0.993289     1.00000  1.006757
# 2             0.993289            0.973154  0.973154     0.97973  1.006757
# 3             0.993289            0.973154  0.973154     0.97973  1.006757
# 6             0.993289            0.973154  0.973154     0.97973  1.006757
# 7             0.993289            0.973154  0.973154     0.97973  1.006757
# 10            0.993289            0.973154  0.973154     0.97973  1.006757
# 11            0.993289            0.973154  0.973154     0.97973  1.006757
#
#     leverage  conviction
# 0   0.006531         inf
# 1   0.006531         inf
# 4   0.006531         inf
# 5   0.006531         inf
# 8   0.006531         inf
# 9   0.006531         inf
# 12  0.006666         inf
# 13  0.006666         inf
# 2   0.006531    1.324385
# 3   0.006531    1.324385
# 6   0.006531    1.324385
# 7   0.006531    1.324385
# 10  0.006531    1.324385
# 11  0.006531    1.324385

# %%
from mlxtend.frequent_patterns import apriori
ans1=apriori(df_new,min_support=0.97, use_colnames=True)
ans1.head(5)
# Out:
#     support         itemsets
# 0  0.979866     (LowDegreeF)
# 1  0.993289     (LowDegreeN)
# 2  0.979866     (LowDegreeO)
# 3  0.979866  (LowNonDegreeF)
# 4  0.993289  (LowNonDegreeN)

# %%
ap=association_rules(ans1,metric='lift',min_threshold=1)
ap=ap.sort_values(['confidence','lift'],ascending=[False, False])
ap.head(15)
# Out:
#                        antecedents                     consequents  \
# 0                     (LowDegreeN)                 (LowNonDegreeN)
# 1                  (LowNonDegreeN)                    (LowDegreeN)
# 2         (LowDegreeN, LowDegreeF)                 (LowNonDegreeN)
# 3      (LowNonDegreeN, LowDegreeF)                    (LowDegreeN)
# 6         (LowDegreeN, LowDegreeO)                 (LowNonDegreeN)
# 7      (LowNonDegreeN, LowDegreeO)                    (LowDegreeN)
# 10     (LowDegreeN, LowNonDegreeF)                 (LowNonDegreeN)
# 11  (LowNonDegreeN, LowNonDegreeF)                    (LowDegreeN)
# 4                     (LowDegreeN)     (LowNonDegreeN, LowDegreeF)
# 5                  (LowNonDegreeN)        (LowDegreeN, LowDegreeF)
# 8                     (LowDegreeN)     (LowNonDegreeN, LowDegreeO)
# 9                  (LowNonDegreeN)        (LowDegreeN, LowDegreeO)
# 12                    (LowDegreeN)  (LowNonDegreeN, LowNonDegreeF)
# 13                 (LowNonDegreeN)     (LowDegreeN, LowNonDegreeF)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.993289            0.993289  0.993289     1.00000  1.006757
# 1             0.993289            0.993289  0.993289     1.00000  1.006757
# 2             0.973154            0.993289  0.973154     1.00000  1.006757
# 3             0.973154            0.993289  0.973154     1.00000  1.006757
# 6             0.973154            0.993289  0.973154     1.00000  1.006757
# 7             0.973154            0.993289  0.973154     1.00000  1.006757
# 10            0.973154            0.993289  0.973154     1.00000  1.006757
# 11            0.973154            0.993289  0.973154     1.00000  1.006757
# 4             0.993289            0.973154  0.973154     0.97973  1.006757
# 5             0.993289            0.973154  0.973154     0.97973  1.006757
# 8             0.993289            0.973154  0.973154     0.97973  1.006757
# 9             0.993289            0.973154  0.973154     0.97973  1.006757
# 12            0.993289            0.973154  0.973154     0.97973  1.006757
# 13            0.993289            0.973154  0.973154     0.97973  1.006757
#
#     leverage  conviction
# 0   0.006666         inf
# 1   0.006666         inf
# 2   0.006531         inf
# 3   0.006531         inf
# 6   0.006531         inf
# 7   0.006531         inf
# 10  0.006531         inf
# 11  0.006531         inf
# 4   0.006531    1.324385
# 5   0.006531    1.324385
# 8   0.006531    1.324385
# 9   0.006531    1.324385
# 12  0.006531    1.324385
# 13  0.006531    1.324385
